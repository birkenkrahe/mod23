# %% [markdown]
# # Dysfunctions - functions with problems

# %% [markdown]
# ## Example function

# %% [markdown]
# As an example function, we use a function that computes the
# carrying capacity `K` for the population model:

# %%
# function definition

# load System function from modsim

# system definition

# compute carrying capacity 

# print system and carrying capacity

# %% [markdown]
# This function is so simple - what could possibly go wrong? If
# only&#x2026;

# %% [markdown]
# ## Dysfunction #1

# %% [markdown]
# This function definition has problems:

# %%
# wrong function definition
def carrying_capacity1():
    K = - sys1.alpha / sys1.beta
    return K

sys1 = System(alpha = 0.025,    beta = -0.0018)
pop = carrying_capacity1()
print(f'System: {sys1}\nCarrying capacity K = {pop}')
# Out:
# System: System(alpha=0.025, beta=-0.0018)
# Carrying capacity K = 13.88888888888889

# %% [markdown]
# Issues:
#
# Lesson:

# %% [markdown]
# ## Dysfunction #2

# %% [markdown]
# What's wrong with this definition?

# %%
# Wrong function definition
def carrying_capacity2(system):
    system = System(alpha=0.025,beta=-0.0018)
    K = - system.alpha / system.beta
    return K

sys1 = System(alpha = 0.025, beta = -0.0017)
pop = carrying_capacity2(sys1)
print(f'System: {sys1}\nCarrying capacity K = {pop}')

# %% [markdown]
# Issues:
#
# Lesson:

# %% [markdown]
# ## Dysfunction #3

# %% [markdown]
# What's the problem here?

# %%
def carrying_capacity3(system):
    K = - system.alpha / system.beta

    
sys1 = System(alpha = 0.025, beta = -0.0017)
pop = carrying_capacity3(sys1)
print(f'System: {sys1}\nCarrying capacity K = {pop}')

# %% [markdown]
# Issues:
#
# Lesson:

# %% [markdown]
# ## Dysfunction #4

# %% [markdown]
# What's wrong here?

# %%
# function definition
def carrying_capacity4(system):
    K = - system.alpha / system.beta
    return K

# system initiation
sys1 = System(alpha = 0.025, beta = -0.0017)

# function call
carrying_capacity4(sys1)

# print results
print(f'System: {sys1}\nCarrying capacity K = {K}')

# %% [markdown]
# Issues:
#
# Lesson:
